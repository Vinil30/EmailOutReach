# %%
from Graph import automated_graph
from IPython.display import Image, display

graph = automated_graph.compile()

display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# %%
from Graph import huamn_in_loop_graph
from IPython.display import Image, display

graph = huamn_in_loop_graph.compile()

display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)
